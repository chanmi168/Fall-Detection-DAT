# %% [markdown]
# # import packages and get authenticated

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at drive

# %%
import numpy as np

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc( 'savefig', facecolor = 'white' )

import pandas as pd
pd.set_option('display.max_columns', 500)
from tqdm import tqdm_notebook as tqdm
import os
import sys
sys.path.append('/content/drive/My Drive/中研院/repo/')

from utilities import *

import time
import datetime
from datetime import datetime

from sklearn.decomposition import PCA

# %%
# def data_saver(data, name, outputdir):
#     """ usage: data_saver(df_merged_interp_alldicts, 'data', outputdir)"""
#     outputdir_data = os.path.join(outputdir, name+'.npz')
#     print('outputdir for {}:'.format(name), outputdir_data)
#     np.savez(outputdir_data, data=data, allow_pickle=True)
#     loaded_data = np.load(outputdir_data, allow_pickle=True)['data']
# #     loaded_data = np.load(outputdir_data, allow_pickle=True)['data']
#     print('Are {} save and loadded correctly? '.format(name), np.array_equal(loaded_data, data))
#     print('')
    
# def data_loader(name, inputdir):
#     """ usage: data = data_loader('data', outputdir)"""
#     inputdir_data = os.path.join(inputdir, name+'.npz')
#     data = np.load(inputdir_data, allow_pickle=True)['data']
#     return data

# %% [markdown]
# ## build 'all' dataset

# %%
dataset_name = 'UMAFall'
sensor_locs = ['waist', 'wrist', 'chest', 'ankle', 'leg']
input_dim = 66


for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)

  
dataset_name = 'UPFall'
sensor_locs = ['ankle', 'wrist', 'rightpocket', 'belt', 'neck']
input_dim = 66

for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)

# %% [markdown]
# ## make all but waist

# %%
dataset_name = 'UMAFall'
sensor_locs = ['wrist', 'chest', 'ankle', 'leg']
input_dim = 66


for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butwaist',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)

dataset_name = 'UPFall'
sensor_locs = ['ankle', 'wrist', 'rightpocket', 'neck']
input_dim = 66

for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butwaist',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)
# Out:
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwaist/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwaist/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True

# %% [markdown]
# ## make all but wrist

# %%
dataset_name = 'UMAFall'
sensor_locs = ['waist', 'chest', 'ankle', 'leg']
input_dim = 66


for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butwrist',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)

dataset_name = 'UPFall'
sensor_locs = ['ankle', 'rightpocket', 'belt', 'neck']
input_dim = 66

for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butwrist',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)
# Out:
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butwrist/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butwrist/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True

# %% [markdown]
# ## make all but ankle

# %%
dataset_name = 'UMAFall'
sensor_locs = ['waist', 'wrist', 'chest', 'leg']
input_dim = 66


for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butankle',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)

dataset_name = 'UPFall'
sensor_locs = ['wrist', 'rightpocket', 'belt', 'neck']
input_dim = 66

for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butankle',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)
# Out:
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butankle/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butankle/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True

# %% [markdown]
# ## make all but wrist

# %%
dataset_name = 'UMAFall'
sensor_locs = ['waist', 'wrist', 'chest', 'ankle']
input_dim = 66


for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butleg',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)

dataset_name = 'UPFall'
sensor_locs = ['ankle', 'wrist', 'belt', 'neck']
input_dim = 66

for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butleg',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)
# Out:
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butleg/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butleg/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True

# %% [markdown]
# ## make all but fifth

# %%
dataset_name = 'UMAFall'
sensor_locs = ['waist', 'wrist', 'ankle', 'leg']
input_dim = 66


for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butfifth',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)

  
dataset_name = 'UPFall'
sensor_locs = ['ankle', 'wrist', 'rightpocket', 'belt']
input_dim = 66

for i_CV in range(5):
  inputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/'
  outputdir = '/content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/{}/{}/CV{}'.format(dataset_name, 'all_butfifth',i_CV)
  if not os.path.exists(outputdir):
      os.makedirs(outputdir)
  print('outputdir for train:', outputdir)
  combine_data(input_dim, dataset_name, sensor_locs, i_CV, inputdir, outputdir)
# Out:
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UMAFall/all_butfifth/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV0/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV1/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV2/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV3/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4
# outputdir for train: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/train
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/train/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/train/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/train/i_sub.npz
# Are i_sub save and loadded correctly?  True
#
# outputdir for val: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/val
# outputdir for data: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/val/data.npz
# Are data save and loadded correctly?  True
#
# outputdir for labels: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/val/labels.npz
# Are labels save and loadded correctly?  True
#
# outputdir for i_sub: /content/drive/My Drive/中研院/data_mic/stage1_preprocessed_18hz/UPFall/all_butfifth/CV4/val/i_sub.npz
# Are i_sub save and loadded correctly?  True
