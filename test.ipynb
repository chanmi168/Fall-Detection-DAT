# %%
from google.colab import drive
drive.mount._DEBUG = True
drive.mount('drive')
# Out:
# export PS1="root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: "
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# root@d42b12405443:/content# root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: umount -f drive || umount drive; pkill -9 -x drive
# umount: drive: no mount point specified.
# umount: drive: no mount point specified.
# root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: ( while `sleep 0.5`; do if [[ -d "drive" && "$(ls -A drive)" != "" ]]; then echo "google.colab.drive MOUNTED"; break; fi; done ) &
# [1] 163
# root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: cat /tmp/tmpbosh7_u6/drive.fifo | head -1 | ( /opt/google/drive/drive --features=max_parallel_push_task_instances:10,max_operation_batch_size:15,opendir_timeout_ms:60000,virtual_folders:true --inet_family=IPV4_ONLY --preferences=trusted_root_certs_file_path:/opt/google/drive/roots.pem,mount_point_path:drive --console_auth 2>&1 | grep --line-buffered -E "(Go to this URL in a browser: https://.*)$|Drive File Stream encountered a problem and has stopped"; echo "drive EXITED"; ) &
# [2] 166
# root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# google.colab.drive MOUNTED
# rm -rf "/root/.config/Google/DriveFS/Logs/timeouts.txt"
# root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: nohup bash -c 'tail -n +0 -F "/root/.config/Google/DriveFS/Logs/drive_fs.txt" | grep --line-buffered "QueryManager timed out" > "/root/.config/Google/DriveFS/Logs/timeouts.txt" ' < /dev/null > /dev/null 2>&1 &
# [3] 310
# root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: disown -a
# root@d42b12405443-8c7257cb0abe4094bda7e9832830cd39: exit
# Mounted at drive

# %%
# function ClickConnect(){
# console.log("Working"); 
# document.querySelector("colab-toolbar-button#connect").click() 
# }
# setInterval(ClickConnect,60000)
# Out:
#   File "<ipython-input-1-2f509b6833c1>", line 1
#     function ClickConnect(){
#                         ^
# SyntaxError: invalid syntax

# %%
#!/bin/bash

# !set -e
# !set -u
# %cd /content/drive/My Drive/中研院/repo/

# !jupyter nbconvert --to python stage2_ConvNet.ipynb
# Out:
# /content/drive/My Drive/中研院/repo
# [NbConvertApp] Converting notebook stage2_ConvNet.ipynb to python
# [NbConvertApp] Writing 10099 bytes to stage2_ConvNet.py

# %%
# !python stage2_ConvNet.py
# %ls
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# export PS1="root@d42b12405443-9b9bd0afcadf4db3a821a83dfd21aca5: "
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# root@d42b12405443:/content/drive/My Drive/中研院/repo# root@d42b12405443-9b9bd0afcadf4db3a821a83dfd21aca5: umount -f drive || umount drive; pkill -9 -x drive
# umount: /content/drive: target is busy.
# umount: /content/drive: target is busy.
# root@d42b12405443-9b9bd0afcadf4db3a821a83dfd21aca5: ( while `sleep 0.5`; do if [[ -d "drive" && "$(ls -A drive)" != "" ]]; then echo "google.colab.drive MOUNTED"; break; fi; done ) &
# [1] 341
# root@d42b12405443-9b9bd0afcadf4db3a821a83dfd21aca5: cat /tmp/tmp0srq6r7s/drive.fifo | head -1 | ( /opt/google/drive/drive --features=max_parallel_push_task_instances:10,max_operation_batch_size:15,opendir_timeout_ms:60000,virtual_folders:true --inet_family=IPV4_ONLY --preferences=trusted_root_certs_file_path:/opt/google/drive/roots.pem,mount_point_path:drive --console_auth 2>&1 | grep --line-buffered -E "(Go to this URL in a browser: https://.*)$|Drive File Stream encountered a problem and has stopped"; echo "drive EXITED"; ) &
# [2] 345
# root@d42b12405443-9b9bd0afcadf4db3a821a83dfd21aca5: drive EXITED
# Traceback (most recent call last):
#   File "stage2_ConvNet.py", line 11, in <module>
#   File "/usr/local/lib/python3.6/dist-packages/google/colab/drive.py", line 233, in mount
#     raise ValueError('mount failed' + extra_reason)
# ValueError: mount failed

# %%
# %cd /content/drive/My Drive/中研院/repo/
# Out:
# [Errno 2] No such file or directory: '/content/drive/My Drive/中研院/repo/'
# /content

# %%
# !cd /content
# !pwd
# Out:
# /content/drive/My Drive/中研院/repo
